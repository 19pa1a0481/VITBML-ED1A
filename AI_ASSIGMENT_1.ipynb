# %% [markdown]
# <a href="https://colab.research.google.com/github/19pa1a0481/VITBML-ED1A/blob/master/AI_ASSIGMENT_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
c=pd.read_csv("/content/BPD_Part_1_Victim_Based_Crime_Data.csv (8).zip")
c
# Out:
#          CrimeDate CrimeTime  ...     Premise Total Incidents
# 0       09/02/2017  23:30:00  ...  ROW/TOWNHO               1
# 1       09/02/2017  23:00:00  ...      STREET               1
# 2       09/02/2017  22:53:00  ...      Street               1
# 3       09/02/2017  22:50:00  ...  ROW/TOWNHO               1
# 4       09/02/2017  22:31:00  ...      STREET               1
# ...            ...       ...  ...         ...             ...
# 276524  01/01/2012  00:00:00  ...  OTHER - IN               1
# 276525  01/01/2012  00:00:00  ...  OTHER - OU               1
# 276526  01/01/2012  00:00:00  ...      STREET               1
# 276527  01/01/2012  00:00:00  ...  APT. LOCKE               1
# 276528  01/01/2012  00:00:00  ...  ROW/TOWNHO               1
#
# [276529 rows x 15 columns]

# %% [markdown]
# #**checking data dimensions**

# %%
print(c.shape)
# Out:
# (276529, 15)

# %% [markdown]
# #**data inspecton**

# %%
## getting top three rows of data using head method
c.head(3)
# Out:
#     CrimeDate CrimeTime  ...     Premise Total Incidents
# 0  09/02/2017  23:30:00  ...  ROW/TOWNHO               1
# 1  09/02/2017  23:00:00  ...      STREET               1
# 2  09/02/2017  22:53:00  ...      Street               1
#
# [3 rows x 15 columns]

# %%
## columns give the column names of the given data
 print(c.columns)
# Out:
# Index(['CrimeDate', 'CrimeTime', 'CrimeCode', 'Location', 'Description',
#        'Inside/Outside', 'Weapon', 'Post', 'District', 'Neighborhood',
#        'Longitude', 'Latitude', 'Location 1', 'Premise', 'Total Incidents'],
#       dtype='object')

# %% [markdown]
# #**data types**

# %%
## dtypes gives datatypes for each column
print(c.dtypes)
# Out:
# CrimeDate           object
# CrimeTime           object
# CrimeCode           object
# Location            object
# Description         object
# Inside/Outside      object
# Weapon              object
# Post               float64
# District            object
# Neighborhood        object
# Longitude          float64
# Latitude           float64
# Location 1          object
# Premise             object
# Total Incidents      int64
# dtype: object

# %% [markdown]
# #**central tendency**

# %%
#sorting data
sorted(c)
c
# Out:
#          CrimeDate CrimeTime  ...     Premise Total Incidents
# 0       09/02/2017  23:30:00  ...  ROW/TOWNHO               1
# 1       09/02/2017  23:00:00  ...      STREET               1
# 2       09/02/2017  22:53:00  ...      Street               1
# 3       09/02/2017  22:50:00  ...  ROW/TOWNHO               1
# 4       09/02/2017  22:31:00  ...      STREET               1
# ...            ...       ...  ...         ...             ...
# 276524  01/01/2012  00:00:00  ...  OTHER - IN               1
# 276525  01/01/2012  00:00:00  ...  OTHER - OU               1
# 276526  01/01/2012  00:00:00  ...      STREET               1
# 276527  01/01/2012  00:00:00  ...  APT. LOCKE               1
# 276528  01/01/2012  00:00:00  ...  ROW/TOWNHO               1
#
# [276529 rows x 15 columns]

# %%
type(c)
# Out:
# pandas.core.frame.DataFrame

# %%
# to find the median of the data set using medinan
c.median()
# Out:
# Post               511.00000
# Longitude          -76.61396
# Latitude            39.30364
# Total Incidents      1.00000
# dtype: float64

# %%
# to find mode of dataset using mode
 c.mode()
# Out:
#     CrimeDate CrimeTime  ... Premise Total Incidents
# 0  04/27/2015  18:00:00  ...  STREET               1
#
# [1 rows x 15 columns]

# %%
# mean for axis=1
c.mean(axis=1)
# Out:
# 0         219.156025
# 1          24.170358
# 2         121.935178
# 3         224.409472
# 4          19.168477
#              ...
# 276524    198.897342
# 276525    101.946660
# 276526     71.177690
# 276527     97.200307
# 276528    198.654010
# Length: 276529, dtype: float64

# %% [markdown]
# #**variability**

# %%
# standard deviation
# degree of ferrdom=0
#divided by n insted of dividedby n-1
c.std(ddof=0)
# Out:
# Post               260.734898
# Longitude            0.042306
# Latitude             0.029556
# Total Incidents      0.000000
# dtype: float64

# %% [markdown]
# #**about the distibution**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
a=c.tail(10)
a.plot(kind="bar")
plt.show()

# %%
# handiling missing values(dealing with NA)
# find for NA'S
c.isna()
# Out:
#         CrimeDate  CrimeTime  CrimeCode  ...  Location 1  Premise  Total Incidents
# 0           False      False      False  ...       False    False            False
# 1           False      False      False  ...       False    False            False
# 2           False      False      False  ...       False    False            False
# 3           False      False      False  ...       False    False            False
# 4           False      False      False  ...       False    False            False
# ...           ...        ...        ...  ...         ...      ...              ...
# 276524      False      False      False  ...       False    False            False
# 276525      False      False      False  ...       False    False            False
# 276526      False      False      False  ...       False    False            False
# 276527      False      False      False  ...       False    False            False
# ...

# %%
#fill NA's with zeros in dataset
c.fillna(0)
# Out:
#          CrimeDate CrimeTime  ...     Premise Total Incidents
# 0       09/02/2017  23:30:00  ...  ROW/TOWNHO               1
# 1       09/02/2017  23:00:00  ...      STREET               1
# 2       09/02/2017  22:53:00  ...      Street               1
# 3       09/02/2017  22:50:00  ...  ROW/TOWNHO               1
# 4       09/02/2017  22:31:00  ...      STREET               1
# ...            ...       ...  ...         ...             ...
# 276524  01/01/2012  00:00:00  ...  OTHER - IN               1
# 276525  01/01/2012  00:00:00  ...  OTHER - OU               1
# 276526  01/01/2012  00:00:00  ...      STREET               1
# 276527  01/01/2012  00:00:00  ...  APT. LOCKE               1
# 276528  01/01/2012  00:00:00  ...  ROW/TOWNHO               1
#
# [276529 rows x 15 columns]

# %%
#fill NA's with previous value in dataset
c.fillna(method='pad')
# Out:
#          CrimeDate CrimeTime  ...     Premise Total Incidents
# 0       09/02/2017  23:30:00  ...  ROW/TOWNHO               1
# 1       09/02/2017  23:00:00  ...      STREET               1
# 2       09/02/2017  22:53:00  ...      Street               1
# 3       09/02/2017  22:50:00  ...  ROW/TOWNHO               1
# 4       09/02/2017  22:31:00  ...      STREET               1
# ...            ...       ...  ...         ...             ...
# 276524  01/01/2012  00:00:00  ...  OTHER - IN               1
# 276525  01/01/2012  00:00:00  ...  OTHER - OU               1
# 276526  01/01/2012  00:00:00  ...      STREET               1
# 276527  01/01/2012  00:00:00  ...  APT. LOCKE               1
# 276528  01/01/2012  00:00:00  ...  ROW/TOWNHO               1
#
# [276529 rows x 15 columns]

# %%
#fill NA's with next value in dataset
c.fillna(method='bfill')
# Out:
#          CrimeDate CrimeTime  ...     Premise Total Incidents
# 0       09/02/2017  23:30:00  ...  ROW/TOWNHO               1
# 1       09/02/2017  23:00:00  ...      STREET               1
# 2       09/02/2017  22:53:00  ...      Street               1
# 3       09/02/2017  22:50:00  ...  ROW/TOWNHO               1
# 4       09/02/2017  22:31:00  ...      STREET               1
# ...            ...       ...  ...         ...             ...
# 276524  01/01/2012  00:00:00  ...  OTHER - IN               1
# 276525  01/01/2012  00:00:00  ...  OTHER - OU               1
# 276526  01/01/2012  00:00:00  ...      STREET               1
# 276527  01/01/2012  00:00:00  ...  APT. LOCKE               1
# 276528  01/01/2012  00:00:00  ...  ROW/TOWNHO               1
#
# [276529 rows x 15 columns]

# %%
#fillNA's with constant/text
 c.fillna("not available",inplace=True)
c
# Out:
#          CrimeDate CrimeTime  ...     Premise Total Incidents
# 0       09/02/2017  23:30:00  ...  ROW/TOWNHO               1
# 1       09/02/2017  23:00:00  ...      STREET               1
# 2       09/02/2017  22:53:00  ...      Street               1
# 3       09/02/2017  22:50:00  ...  ROW/TOWNHO               1
# 4       09/02/2017  22:31:00  ...      STREET               1
# ...            ...       ...  ...         ...             ...
# 276524  01/01/2012  00:00:00  ...  OTHER - IN               1
# 276525  01/01/2012  00:00:00  ...  OTHER - OU               1
# 276526  01/01/2012  00:00:00  ...      STREET               1
# 276527  01/01/2012  00:00:00  ...  APT. LOCKE               1
# 276528  01/01/2012  00:00:00  ...  ROW/TOWNHO               1
#
# [276529 rows x 15 columns]

# %%
# use interplote function to fill the missing value which are in dataset
c.interpolate(method="linear")
# Out:
#          CrimeDate CrimeTime  ...     Premise Total Incidents
# 0       09/02/2017  23:30:00  ...  ROW/TOWNHO               1
# 1       09/02/2017  23:00:00  ...      STREET               1
# 2       09/02/2017  22:53:00  ...      Street               1
# 3       09/02/2017  22:50:00  ...  ROW/TOWNHO               1
# 4       09/02/2017  22:31:00  ...      STREET               1
# ...            ...       ...  ...         ...             ...
# 276524  01/01/2012  00:00:00  ...  OTHER - IN               1
# 276525  01/01/2012  00:00:00  ...  OTHER - OU               1
# 276526  01/01/2012  00:00:00  ...      STREET               1
# 276527  01/01/2012  00:00:00  ...  APT. LOCKE               1
# 276528  01/01/2012  00:00:00  ...  ROW/TOWNHO               1
#
# [276529 rows x 15 columns]

# %%
# removing rows with NA's in dataset
c.dropna()
# Out:
#          CrimeDate CrimeTime  ...     Premise Total Incidents
# 0       09/02/2017  23:30:00  ...  ROW/TOWNHO               1
# 1       09/02/2017  23:00:00  ...      STREET               1
# 2       09/02/2017  22:53:00  ...      Street               1
# 3       09/02/2017  22:50:00  ...  ROW/TOWNHO               1
# 4       09/02/2017  22:31:00  ...      STREET               1
# ...            ...       ...  ...         ...             ...
# 276524  01/01/2012  00:00:00  ...  OTHER - IN               1
# 276525  01/01/2012  00:00:00  ...  OTHER - OU               1
# 276526  01/01/2012  00:00:00  ...      STREET               1
# 276527  01/01/2012  00:00:00  ...  APT. LOCKE               1
# 276528  01/01/2012  00:00:00  ...  ROW/TOWNHO               1
#
# [276529 rows x 15 columns]

# %%
# remove row which all NA's
c.dropna(how="all")
# Out:
#          CrimeDate CrimeTime  ...     Premise Total Incidents
# 0       09/02/2017  23:30:00  ...  ROW/TOWNHO               1
# 1       09/02/2017  23:00:00  ...      STREET               1
# 2       09/02/2017  22:53:00  ...      Street               1
# 3       09/02/2017  22:50:00  ...  ROW/TOWNHO               1
# 4       09/02/2017  22:31:00  ...      STREET               1
# ...            ...       ...  ...         ...             ...
# 276524  01/01/2012  00:00:00  ...  OTHER - IN               1
# 276525  01/01/2012  00:00:00  ...  OTHER - OU               1
# 276526  01/01/2012  00:00:00  ...      STREET               1
# 276527  01/01/2012  00:00:00  ...  APT. LOCKE               1
# 276528  01/01/2012  00:00:00  ...  ROW/TOWNHO               1
#
# [276529 rows x 15 columns]

# %%
3 remove the coloums contain NA's
c.dropna(axis=1)
# Out:
#          CrimeDate CrimeTime  ...     Premise Total Incidents
# 0       09/02/2017  23:30:00  ...  ROW/TOWNHO               1
# 1       09/02/2017  23:00:00  ...      STREET               1
# 2       09/02/2017  22:53:00  ...      Street               1
# 3       09/02/2017  22:50:00  ...  ROW/TOWNHO               1
# 4       09/02/2017  22:31:00  ...      STREET               1
# ...            ...       ...  ...         ...             ...
# 276524  01/01/2012  00:00:00  ...  OTHER - IN               1
# 276525  01/01/2012  00:00:00  ...  OTHER - OU               1
# 276526  01/01/2012  00:00:00  ...      STREET               1
# 276527  01/01/2012  00:00:00  ...  APT. LOCKE               1
# 276528  01/01/2012  00:00:00  ...  ROW/TOWNHO               1
#
# [276529 rows x 15 columns]

# %% [markdown]
# #**grouping the data**

# %%
c.groupby(by='CrimeDate').groups
# Out:
# {'01/01/2012': Int64Index([276353, 276354, 276355, 276356, 276357, 276358, 276359, 276360,
#              276361, 276362,
#              ...
#              276519, 276520, 276521, 276522, 276523, 276524, 276525, 276526,
#              276527, 276528],
#             dtype='int64', length=176),
#  '01/01/2013': Int64Index([226801, 226802, 226803, 226804, 226805, 226806, 226807, 226808,
#              226809, 226810,
#              ...
#              226948, 226949, 226950, 226951, 226952, 226953, 226954, 226955,
#              226956, 226957],
#             dtype='int64', length=157),
#  '01/01/2014': Int64Index([177248, 177249, 177250, 177251, 177252, 177253, 177254, 177255,
#              177256, 177257,
#              ...
#              177378, 177379, 177380, 177381, 177382, 177383, 177384, 177385,
#              177386, 177387],
#             dtype='int64', length=140),
#  '01/01/2015': Int64Index([131262, 131263, 131264, 131265, 131266, 131267, 131268, 131269,
# ...

# %% [markdown]
# #**graphical representation**

# %%
import matplotlib.pyplot as plt
a=c.head(12)
a.plot(kind="bar")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
a=c.head(11)
a.plot(kind="hist")
plt.show()

# %%
a=c["CrimeDate"]
n=c["CrimeTime"]
plt.scatter(a,n,c="green")

# %% [markdown]
# #**correlation**

# %%
# to find corelation in dataset by corr()
corrMatrix=c.corr()
corrMatrix
# Out:
#                  Total Incidents
# Total Incidents              NaN

# %%
pd.DataFrame(c)
# Out:
#          CrimeDate CrimeTime  ...     Premise Total Incidents
# 0       09/02/2017  23:30:00  ...  ROW/TOWNHO               1
# 1       09/02/2017  23:00:00  ...      STREET               1
# 2       09/02/2017  22:53:00  ...      Street               1
# 3       09/02/2017  22:50:00  ...  ROW/TOWNHO               1
# 4       09/02/2017  22:31:00  ...      STREET               1
# ...            ...       ...  ...         ...             ...
# 276524  01/01/2012  00:00:00  ...  OTHER - IN               1
# 276525  01/01/2012  00:00:00  ...  OTHER - OU               1
# 276526  01/01/2012  00:00:00  ...      STREET               1
# 276527  01/01/2012  00:00:00  ...  APT. LOCKE               1
# 276528  01/01/2012  00:00:00  ...  ROW/TOWNHO               1
#
# [276529 rows x 15 columns]

# %% [markdown]
# #**Qestions**
# #**1.How many features are present in dataset?**
# #**2.How many numerical features are present?**
# #**3.How many labes are present?**
# #**4.What is the mean value of the given data?**
# #**5.What is median of the dataset?**
# #**6.How many rows and columns?**
# #**7.Where the more crime happen?**
# #**8.when the more crimr happen?**

# %% [markdown]
# #**conclusion**
# From the dataset analysis we came to know about no of crime from last 10 years from dataset.In the dataset we came across features.from this features we can complete analysis the crimedata.

# %% [markdown]
# #**contributors**
# #**19pa1a0481-k.kotti**
# #**19pa1a04b2-n.parasuram**
# #**19pa1a04a3-M.madhu babu**
# #**19pa1a04b4-N.udaysankar**
